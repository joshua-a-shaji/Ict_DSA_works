# %% [markdown]
# <a href="https://colab.research.google.com/github/joshua-a-shaji/Ict_DSA_works/blob/main/Deep_learning_Casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.datasets import cifar100

from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense, Flatten, Dropout,GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

from tensorflow.keras.preprocessing.image import ImageDataGenerator




import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load dataset

# %%
# Load dataset
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

print(x_train.shape)
print(x_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# ## Normalizing

# %%
## Normalize pixel value

x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# ## One-hot encode

# %%
# One-hot encoding

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

# %% [markdown]
# ## Custom CNN

# %%
model_cnn = models.Sequential()

# First Convolution Block
model_cnn.add(layers.Conv2D(
    32,
    (3,3),
    activation='relu',
    padding='same',
    kernel_initializer='he_normal',
    input_shape=(32,32,3)
))

model_cnn.add(layers.BatchNormalization())

model_cnn.add(layers.Conv2D(
    32,
    (3,3),
    activation='relu',
    padding='same'
))

model_cnn.add(layers.MaxPooling2D((2,2)))
model_cnn.add(layers.Dropout(0.25))

# Second Convolution Block
model_cnn.add(layers.Conv2D(
    64,
    (3,3),
    activation='relu',
    padding='same'
))

model_cnn.add(layers.BatchNormalization())

model_cnn.add(layers.Conv2D(
    64,
    (3,3),
    activation='relu',
    padding='same'
))

model_cnn.add(layers.MaxPooling2D((2,2)))
model_cnn.add(layers.Dropout(0.25))

# Third Convolution Block
model_cnn.add(layers.Conv2D(
    128,
    (3,3),
    activation='relu',
    padding='same'
))

model_cnn.add(layers.BatchNormalization())

model_cnn.add(layers.MaxPooling2D((2,2)))
model_cnn.add(layers.Dropout(0.3))

# Flatten Layer
model_cnn.add(layers.Flatten())

# Fully Connected Layer
model_cnn.add(layers.Dense(
    256,
    activation='relu',
    kernel_regularizer=tf.keras.regularizers.l2(0.001)
))

model_cnn.add(layers.Dropout(0.5))

# Output Layer
model_cnn.add(layers.Dense(100, activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Compile the model

# %%
model_cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## Model summary

# %%
model_cnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        25,700 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 690,564 (2.63 MB)
#  Trainable params: 690,116 (2.63 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ## Callbacks

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    'best_model.keras',
    save_best_only=True
)

# %% [markdown]
# ## Train the model

# %%
history = model_cnn.fit(
    x_train,
    y_train,
    epochs=30,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.0386 - loss: 4.7728 - val_accuracy: 0.0734 - val_loss: 4.3259
# Epoch 2/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.0925 - loss: 4.1532 - val_accuracy: 0.1270 - val_loss: 3.9354
# Epoch 3/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.1514 - loss: 3.8054 - val_accuracy: 0.2274 - val_loss: 3.4176
# Epoch 4/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2128 - loss: 3.5181 - val_accuracy: 0.3048 - val_loss: 3.0709
# Epoch 5/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.2585 - loss: 3.3232 - val_accuracy: 0.3353 - val_loss: 2.9092
# Epoch 6/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.2928 - loss: 3.1527 - val_accuracy: 0.3702 - val_loss: 2.8057
# Epoch 7/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.3200 - loss: 3.0302 - val_accuracy: 0.3991 - val_loss: 2.6712
# Epoch 8/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.3449 - loss: 2.9335 - val_accuracy: 0.3999 - val_loss: 2.6868
# Epoch 9/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3590 - loss: 2.8600 - val_accuracy: 0.4030 - val_loss: 2.6786
# Epoch 10/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.3661 - loss: 2.8562 - val_accuracy: 0.4157 - val_loss: 2.6425
# Epoch 11/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.3789 - loss: 2.8100 - val_accuracy: 0.4273 - val_loss: 2.5923
# Epoch 12/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.3954 - loss: 2.7084 - val_accuracy: 0.4452 - val_loss: 2.5464
# Epoch 13/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4132 - loss: 2.6163 - val_accuracy: 0.4580 - val_loss: 2.4396
# Epoch 14/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4258 - loss: 2.5520 - val_accuracy: 0.4713 - val_loss: 2.3674
# Epoch 15/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4333 - loss: 2.5109 - val_accuracy: 0.4575 - val_loss: 2.4754
# Epoch 16/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4420 - loss: 2.4819 - val_accuracy: 0.4752 - val_loss: 2.3712
# Epoch 17/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.4480 - loss: 2.4571 - val_accuracy: 0.4913 - val_loss: 2.3015
# Epoch 18/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4561 - loss: 2.4398 - val_accuracy: 0.4908 - val_loss: 2.3260
# Epoch 19/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4589 - loss: 2.4129 - val_accuracy: 0.4840 - val_loss: 2.3584
# Epoch 20/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4623 - loss: 2.4080 - val_accuracy: 0.4999 - val_loss: 2.2965
# Epoch 21/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4701 - loss: 2.3905 - val_accuracy: 0.4937 - val_loss: 2.3081
# Epoch 22/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4725 - loss: 2.3733 - val_accuracy: 0.5053 - val_loss: 2.2878
# Epoch 23/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4766 - loss: 2.3555 - val_accuracy: 0.4895 - val_loss: 2.3302
# Epoch 24/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4807 - loss: 2.3487 - val_accuracy: 0.4930 - val_loss: 2.3595
# Epoch 25/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.4827 - loss: 2.3349 - val_accuracy: 0.4954 - val_loss: 2.3330
# Epoch 26/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4862 - loss: 2.3197 - val_accuracy: 0.5136 - val_loss: 2.2645
# Epoch 27/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4876 - loss: 2.3147 - val_accuracy: 0.5081 - val_loss: 2.2944
# Epoch 28/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.4910 - loss: 2.3011 - val_accuracy: 0.5156 - val_loss: 2.2526
# Epoch 29/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4949 - loss: 2.2816 - val_accuracy: 0.5209 - val_loss: 2.2259
# Epoch 30/30
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.4974 - loss: 2.2779 - val_accuracy: 0.4994 - val_loss: 2.3200

# %% [markdown]
# ## Model evaluation

# %%
cnn_loss, cnn_acc = model_cnn.evaluate(x_test, y_test)

print("Test Accuracy:", cnn_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5302 - loss: 2.2040
# Test Accuracy: 0.5302000045776367

# %% [markdown]
# ## plotting

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()

plt.show()

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Load VGG16 base model

# %% [markdown]
# ## Load dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# %% [markdown]
# ## Resize image

# %%
x_train = tf.image.resize(x_train, (64, 64))
x_test = tf.image.resize(x_test, (64, 64))

# %% [markdown]
# ## Adding VGG16 preprocessing

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input

x_train = preprocess_input(x_train)
x_test = preprocess_input(x_test)

# %% [markdown]
# ## One-hot enoding

# %%
y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

# %% [markdown]
# ## Data argumentation

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

datagen.fit(x_train)

# %% [markdown]
# ## Load pretrained VGG16

# %%
base_model = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(64, 64, 3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# ## FREEZE EARLY LAYERS

# %%
for layer in base_model.layers[:-2]:
    layer.trainable = False

for layer in base_model.layers[-2:]:
    layer.trainable = True

# %% [markdown]
# ## BUILD MODEL

# %%
model = Sequential()

model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(256, activation='relu',kernel_regularizer=l2(0.001)))
model.add(Dropout(0.6))
model.add(Dense(100, activation='softmax'))

# %% [markdown]
# ## Compile Model

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## MOdel summary

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 2, 2, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 100)            │        25,700 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,871,716 (56.73 MB)
#  Trainable params: 2,516,836 (9.60 MB)
#  Non-trainable params: 12,354,880 (47.13 MB)

# %% [markdown]
# ## Callbacks

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    'best_vgg16_model.keras',
    save_best_only=True
)

lr_reduce = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1
)

# %% [markdown]
# ## Train model

# %%
history = model.fit(
    datagen.flow(x_train, y_train, batch_size=16),
    epochs=20,
    validation_data=(x_test, y_test),
    callbacks=[early_stop, checkpoint, lr_reduce]
)
# Out:
# Epoch 1/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 97s 29ms/step - accuracy: 0.1149 - loss: 4.7762 - val_accuracy: 0.3412 - val_loss: 3.1077 - learning_rate: 1.0000e-04
# Epoch 2/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 91s 29ms/step - accuracy: 0.2878 - loss: 3.2758 - val_accuracy: 0.4496 - val_loss: 2.3866 - learning_rate: 1.0000e-04
# Epoch 3/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 91s 29ms/step - accuracy: 0.3767 - loss: 2.6791 - val_accuracy: 0.5033 - val_loss: 2.0554 - learning_rate: 1.0000e-04
# Epoch 4/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 102s 33ms/step - accuracy: 0.4337 - loss: 2.3329 - val_accuracy: 0.5359 - val_loss: 1.8736 - learning_rate: 1.0000e-04
# Epoch 5/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 92s 30ms/step - accuracy: 0.4738 - loss: 2.1190 - val_accuracy: 0.5507 - val_loss: 1.7855 - learning_rate: 1.0000e-04
# Epoch 6/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 97s 31ms/step - accuracy: 0.5068 - loss: 1.9688 - val_accuracy: 0.5670 - val_loss: 1.7165 - learning_rate: 1.0000e-04
# Epoch 7/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 92s 29ms/step - accuracy: 0.5325 - loss: 1.8701 - val_accuracy: 0.5747 - val_loss: 1.6733 - learning_rate: 1.0000e-04
# Epoch 8/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 90s 29ms/step - accuracy: 0.5506 - loss: 1.7734 - val_accuracy: 0.5828 - val_loss: 1.6304 - learning_rate: 1.0000e-04
# Epoch 9/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 103s 33ms/step - accuracy: 0.5702 - loss: 1.6900 - val_accuracy: 0.5871 - val_loss: 1.6135 - learning_rate: 1.0000e-04
# Epoch 10/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 112s 36ms/step - accuracy: 0.5865 - loss: 1.6153 - val_accuracy: 0.5905 - val_loss: 1.6189 - learning_rate: 1.0000e-04
# Epoch 11/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 112s 36ms/step - accuracy: 0.5978 - loss: 1.5657 - val_accuracy: 0.5963 - val_loss: 1.5854 - learning_rate: 1.0000e-04
# Epoch 12/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 105s 34ms/step - accuracy: 0.6130 - loss: 1.5031 - val_accuracy: 0.6039 - val_loss: 1.5907 - learning_rate: 1.0000e-04
# Epoch 13/20
# 3124/3125 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6288 - loss: 1.4307
# Epoch 13: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 105s 34ms/step - accuracy: 0.6249 - loss: 1.4532 - val_accuracy: 0.6090 - val_loss: 1.5863 - learning_rate: 1.0000e-04
# Epoch 14/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 92s 29ms/step - accuracy: 0.6548 - loss: 1.3261 - val_accuracy: 0.6149 - val_loss: 1.5339 - learning_rate: 5.0000e-05
# Epoch 15/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 90s 29ms/step - accuracy: 0.6672 - loss: 1.2709 - val_accuracy: 0.6215 - val_loss: 1.5317 - learning_rate: 5.0000e-05
# Epoch 16/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 90s 29ms/step - accuracy: 0.6782 - loss: 1.2324 - val_accuracy: 0.6193 - val_loss: 1.5299 - learning_rate: 5.0000e-05
# Epoch 17/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 91s 29ms/step - accuracy: 0.6848 - loss: 1.2029 - val_accuracy: 0.6219 - val_loss: 1.5456 - learning_rate: 5.0000e-05
# Epoch 18/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6883 - loss: 1.1662
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 90s 29ms/step - accuracy: 0.6902 - loss: 1.1742 - val_accuracy: 0.6257 - val_loss: 1.5356 - learning_rate: 5.0000e-05
# Epoch 19/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 88s 28ms/step - accuracy: 0.7097 - loss: 1.1004 - val_accuracy: 0.6277 - val_loss: 1.5338 - learning_rate: 2.5000e-05
# Epoch 20/20
# 3125/3125 ━━━━━━━━━━━━━━━━━━━━ 89s 28ms/step - accuracy: 0.7140 - loss: 1.0801 - val_accuracy: 0.6313 - val_loss: 1.5186 - learning_rate: 2.5000e-05

# %% [markdown]
# ## Evaluate Model

# %%
vgg_loss, vgg_acc = model.evaluate(x_test, y_test)

print("Test Accuracy:", vgg_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6313 - loss: 1.5186
# Test Accuracy: 0.6312999725341797

# %% [markdown]
# ## Accuracy Graph

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('VGG16 Accuracy')

plt.legend()
plt.show()

# %% [markdown]
# ## Loss Graph

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('VGG16 Loss')

plt.legend()
plt.show()

# %% [markdown]
# ## Comparison bwtween CNN and VGG16

# %%
import pandas as pd

df_compare = pd.DataFrame({
    "Model": ["Custom CNN", "VGG16"],
    "Test Accuracy": [f"{cnn_acc*100:.2f}%", f"{vgg_acc*100:.2f}%"]
})

df_compare
# Out:
#         Model Test Accuracy
# 0  Custom CNN        53.02%
# 1       VGG16        63.13%
